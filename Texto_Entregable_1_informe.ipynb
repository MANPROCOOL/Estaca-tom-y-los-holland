# %% [markdown]
# # Entregable 1: Análisis Exploratorio de Datos - Airbnb Nueva York
#
# ## 1. Introducción y Motivación
# Para este proyecto, hemos seleccionado el conjunto de datos "Airbnb Open Data" de Nueva York. La motivación principal detrás de esta elección es el impacto significativo que tienen las plataformas de alojamiento temporal en la economía y la dinámica urbana de las grandes ciudades. Nueva York, al ser uno de los destinos turísticos más importantes del mundo, ofrece un terreno de estudio amplio en contenido.
#
# Nuestro objetivo es comprender cómo se estructura la oferta de alojamientos, analizando si existen patrones geográficos marcados que definan el tipo de hospedaje disponible según el distrito (borough).
#
# ### Limitaciones del Dataset
# Antes de seguir con el análisis, es importante reconocer ciertas limitaciones en nuestros datos:
# * **Representatividad:** El dataset solo refleja los alojamientos listados en Airbnb, lo cual no es representativo de todo el mercado inmobiliario o turístico de la ciudad.
# * **Sesgo temporal:** Los datos representan una "foto" en un momento específico, por lo que no capturan la estacionalidad (ej. fluctuaciones de precios o disponibilidad entre verano e invierno).
# * **Calidad de los datos ingresados:** Al ser datos generados por los usuarios, pueden existir sesgos descriptivos, precios atípicos o errores de digitación.

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Variable</th>
#       <th>Significado</th>
#       <th>Unidad</th>
#       <th>Tipo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id</td>
#       <td>Identificador único del listado</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>name</td>
#       <td>Nombre/título del anuncio</td>
#       <td>Texto</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>host_id</td>
#       <td>Identificador único del anfitrión</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>host_identity_verified</td>
#       <td>Si la identidad del host está verificada</td>
#       <td>—</td>
#       <td>Nominal (binaria)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>host_name</td>
#       <td>Nombre del anfitrión</td>
#       <td>Texto</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>neighbourhood_group</td>
#       <td>Distrito/borough de NYC donde está el alojamiento</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>neighbourhood</td>
#       <td>Barrio específico dentro del distrito</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>lat / long</td>
#       <td>Coordenadas geográficas del alojamiento</td>
#       <td>Grados decimales</td>
#       <td>Continua</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>instant_bookable</td>
#       <td>Si se puede reservar sin aprobación previa del...</td>
#       <td>—</td>
#       <td>Nominal (binaria)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>cancellation_policy</td>
#       <td>Política de cancelación del listado</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>room_type</td>
#       <td>Tipo de alojamiento ofrecido</td>
#       <td>—</td>
#       <td>Nominal</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>construction_year</td>
#       <td>Año de construcción del inmueble</td>
#       <td>Año</td>
#       <td>Discreta</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>price</td>
#       <td>Precio por noche del alojamiento</td>
#       <td>USD</td>
#       <td>Continua</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>service_fee</td>
#       <td>Cargo por servicio de la plataforma</td>
#       <td>USD</td>
#       <td>Continua</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>minimum_nights</td>
#       <td>Mínimo de noches exigido por reserva</td>
#       <td>Noches</td>
#       <td>Discreta</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>number_of_reviews</td>
#       <td>Cantidad total de reseñas recibidas</td>
#       <td>Cantidad</td>
#       <td>Discreta</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>last_review</td>
#       <td>Fecha de la última reseña</td>
#       <td>Fecha</td>
#       <td>—</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>reviews_per_month</td>
#       <td>Promedio de reseñas recibidas por mes</td>
#       <td>Reseñas/mes</td>
#       <td>Continua</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>review_rate_number</td>
#       <td>Calificación promedio del listado</td>
#       <td>Escala 1-5</td>
#       <td>Discreta (ordinal)</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>calculated_host_listings_count</td>
#       <td>Cantidad de listados que tiene el mismo host</td>
#       <td>Cantidad</td>
#       <td>Discreta</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>availability_365</td>
#       <td>Días disponibles al año para reservar</td>
#       <td>Días</td>
#       <td>Discreta</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Propuesta de pregunta de investigación formal:
#
# Pregunta: ¿Existe asociación entre el tipo de alojamiento (room_type) ofrecido y el grupo de barrio (neighbourhood_group) en que se ubica, en los listados de Airbnb de Nueva York?
#
# H₀: El tipo de alojamiento es independiente del barrio (no hay asociación).
# H₁: El tipo de alojamiento está asociado al barrio (la distribución de tipos varía significativamente entre barrios).
#
# Test estadístico: Chi-cuadrado de independencia → resultado preliminar: χ² = 2708.85, p < 0.001, se rechaza H₀.
